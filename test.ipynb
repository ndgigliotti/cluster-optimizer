# %%
import numpy as np
import pandas as pd
from cluster_optimizer import ClusterOptimizer
from sklearn import cluster
from sklearn.datasets import load_iris

df, tar = load_iris(return_X_y=True, as_frame=True)
df=pd.DataFrame(df)
df
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# [150 rows x 4 columns]

# %%
grid = {"eps": np.arange(.25, 3.25, .25), "min_samples": [5, 20, 50]}
grid
# Out:
# {'eps': array([0.25, 0.5 , 0.75, 1.  , 1.25, 1.5 , 1.75, 2.  , 2.25, 2.5 , 2.75,
#         3.  ]),
#  'min_samples': [5, 20, 50]}

# %%
search = ClusterOptimizer(cluster.DBSCAN(), grid, n_jobs=1, scoring="silhouette", verbose=10, error_score=-1)

# %%
search.fit(df)
search.best_score_
# Out:
# Fitting 36 candidates.
# [CANDIDATE 1/36] START eps=0.25, min_samples=5..................................
# [CANDIDATE 1/36] END ................eps=0.25, min_samples=5; total time=   0.0s
# [CANDIDATE 2/36] START eps=0.25, min_samples=20.................................
# [CANDIDATE 2/36] END ...............eps=0.25, min_samples=20; total time=   0.0s
# [CANDIDATE 3/36] START eps=0.25, min_samples=50.................................
# [CANDIDATE 3/36] END ...............eps=0.25, min_samples=50; total time=   0.0s
# [CANDIDATE 4/36] START eps=0.5, min_samples=5...................................
# [CANDIDATE 4/36] END .................eps=0.5, min_samples=5; total time=   0.0s
# [CANDIDATE 5/36] START eps=0.5, min_samples=20..................................
# [CANDIDATE 5/36] END ................eps=0.5, min_samples=20; total time=   0.0s
# [CANDIDATE 6/36] START eps=0.5, min_samples=50..................................
# [CANDIDATE 6/36] END ................eps=0.5, min_samples=50; total time=   0.0s
# [CANDIDATE 7/36] START eps=0.75, min_samples=5..................................
# [CANDIDATE 7/36] END ................eps=0.75, min_samples=5; total time=   0.0s
# [CANDIDATE 8/36] START eps=0.75, min_samples=20.................................
# [CANDIDATE 8/36] END ...............eps=0.75, min_samples=20; total time=   0.0s
# [CANDIDATE 9/36] START eps=0.75, min_samples=50.................................
# [CANDIDATE 9/36] END ...............eps=0.75, min_samples=50; total time=   0.0s
# [CANDIDATE 10/36] START eps=1.0, min_samples=5..................................
# [CANDIDATE 10/36] END ................eps=1.0, min_samples=5; total time=   0.0s
# [CANDIDATE 11/36] START eps=1.0, min_samples=20.................................
# [CANDIDATE 11/36] END ...............eps=1.0, min_samples=20; total time=   0.0s
# [CANDIDATE 12/36] START eps=1.0, min_samples=50.................................
# [CANDIDATE 12/36] END ...............eps=1.0, min_samples=50; total time=   0.0s
# [CANDIDATE 13/36] START eps=1.25, min_samples=5.................................
# [CANDIDATE 13/36] END ...............eps=1.25, min_samples=5; total time=   0.0s
# [CANDIDATE 14/36] START eps=1.25, min_samples=20................................
# [CANDIDATE 14/36] END ..............eps=1.25, min_samples=20; total time=   0.0s
# [CANDIDATE 15/36] START eps=1.25, min_samples=50................................
# [CANDIDATE 15/36] END ..............eps=1.25, min_samples=50; total time=   0.0s
# [CANDIDATE 16/36] START eps=1.5, min_samples=5..................................
# [CANDIDATE 16/36] END ................eps=1.5, min_samples=5; total time=   0.0s
# [CANDIDATE 17/36] START eps=1.5, min_samples=20.................................
# [CANDIDATE 17/36] END ...............eps=1.5, min_samples=20; total time=   0.0s
# [CANDIDATE 18/36] START eps=1.5, min_samples=50.................................
# [CANDIDATE 18/36] END ...............eps=1.5, min_samples=50; total time=   0.0s
# [CANDIDATE 19/36] START eps=1.75, min_samples=5.................................
# [CANDIDATE 19/36] END ...............eps=1.75, min_samples=5; total time=   0.0s
# [CANDIDATE 20/36] START eps=1.75, min_samples=20................................
# [CANDIDATE 20/36] END ..............eps=1.75, min_samples=20; total time=   0.0s
# [CANDIDATE 21/36] START eps=1.75, min_samples=50................................
# [CANDIDATE 21/36] END ..............eps=1.75, min_samples=50; total time=   0.0s
# [CANDIDATE 22/36] START eps=2.0, min_samples=5..................................
# [CANDIDATE 22/36] END ................eps=2.0, min_samples=5; total time=   0.0s
# [CANDIDATE 23/36] START eps=2.0, min_samples=20.................................
# [CANDIDATE 23/36] END ...............eps=2.0, min_samples=20; total time=   0.0s
# [CANDIDATE 24/36] START eps=2.0, min_samples=50.................................
# [CANDIDATE 24/36] END ...............eps=2.0, min_samples=50; total time=   0.0s
# [CANDIDATE 25/36] START eps=2.25, min_samples=5.................................
# [CANDIDATE 25/36] END ...............eps=2.25, min_samples=5; total time=   0.0s
# [CANDIDATE 26/36] START eps=2.25, min_samples=20................................
# [CANDIDATE 26/36] END ..............eps=2.25, min_samples=20; total time=   0.0s
# [CANDIDATE 27/36] START eps=2.25, min_samples=50................................
# [CANDIDATE 27/36] END ..............eps=2.25, min_samples=50; total time=   0.0s
# [CANDIDATE 28/36] START eps=2.5, min_samples=5..................................
# [CANDIDATE 28/36] END ................eps=2.5, min_samples=5; total time=   0.0s
# [CANDIDATE 29/36] START eps=2.5, min_samples=20.................................
# [CANDIDATE 29/36] END ...............eps=2.5, min_samples=20; total time=   0.0s
# [CANDIDATE 30/36] START eps=2.5, min_samples=50.................................
# [CANDIDATE 30/36] END ...............eps=2.5, min_samples=50; total time=   0.0s
# [CANDIDATE 31/36] START eps=2.75, min_samples=5.................................
# [CANDIDATE 31/36] END ...............eps=2.75, min_samples=5; total time=   0.0s
# [CANDIDATE 32/36] START eps=2.75, min_samples=20................................
# [CANDIDATE 32/36] END ..............eps=2.75, min_samples=20; total time=   0.0s
# [CANDIDATE 33/36] START eps=2.75, min_samples=50................................
# [CANDIDATE 33/36] END ..............eps=2.75, min_samples=50; total time=   0.0s
# [CANDIDATE 34/36] START eps=3.0, min_samples=5..................................
# [CANDIDATE 34/36] END ................eps=3.0, min_samples=5; total time=   0.0s
# [CANDIDATE 35/36] START eps=3.0, min_samples=20.................................
# [CANDIDATE 35/36] END ...............eps=3.0, min_samples=20; total time=   0.0s
# [CANDIDATE 36/36] START eps=3.0, min_samples=50.................................
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# [CANDIDATE 36/36] END ...............eps=3.0, min_samples=50; total time=   0.0s
# d:\Repositories\cluster-optimizer\cluster_optimizer\search.py:62: UserWarning: Scoring failed. The score for these parameters will be set to -1. Details:
# Traceback (most recent call last):
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in _score
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\search.py", line 54, in <dictcomp>
#     scores = {name: scorers[name](estimator, X) for name in scorers}
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 137, in __call__
#     return self._score(
#   File "d:\Repositories\cluster-optimizer\cluster_optimizer\scorer.py", line 116, in _score
#     return self._sign * self._score_func(X, labels, **self._kwargs)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 118, in silhouette_score
#     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 229, in silhouette_samples
#     check_number_of_labels(len(le.classes_), n_samples)
#   File "C:\Users\ndgig\anaconda3\envs\nlp-env\lib\site-packages\sklearn\metrics\cluster\_unsupervised.py", line 33, in check_number_of_labels
#     raise ValueError(
# ValueError: Number of labels is 1. Valid values are 2 to n_samples - 1 (inclusive)
#
#   warnings.warn(
# 0.6867350732769781
